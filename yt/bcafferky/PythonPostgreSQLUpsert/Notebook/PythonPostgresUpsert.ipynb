# %% [markdown]
# # <center>Using PostgreSQL Upsert</center>
#
# ### Author:  Bryan Cafferky  - For Demonstration Purposes Only
#
# ### Not intended for production use.

# %% [markdown]
# ### If you don't have SQLAlchemy installed uncomment one fo the 2 cells below and execute it to install SQLLAlchemy.

# %%
# pip install sqlalchemy  # Run only if you do not have SQLAlchemy installed!

# %%
# conda install -c anaconda sqlalchemy # Using Conda - Run only if you do not have SQLAlchemy installed!

# %%
# !pip show sqlalchemy
# Out:
# Name: SQLAlchemy
# Version: 2.0.43
# Summary: Database Abstraction Library
# Home-page: https://www.sqlalchemy.org
# Author: Mike Bayer
# Author-email: mike_mp@zzzcomputing.com
# License: MIT
# Location: /Users/romadv-mac/dev_mac/venv312/lib/python3.13/site-packages
# Requires: typing-extensions
# Required-by: pandasql

# %% [markdown]
# ### PostgreSQL is CASE SENSITIVE so we will stick to lower case.

# %%
from sqlalchemy import create_engine

# connection string: driver://username:password@server/database
engine = create_engine('postgresql+psycopg2://postgres:hn@localhost/postgres')

# %% [markdown]
# ### We need to create the table with a primary key before saving data to it.
# ### The Primary Key uniquely identifies each row which we need so we can tell PostgreSQL which rows to Update or Delete.

# %%
conn = engine.connect()
conn.exec_driver_sql('DROP TABLE IF EXISTS youtube_customer')
conn.exec_driver_sql('DROP TABLE IF EXISTS youtube_cust_trans')

# %%
conn.exec_driver_sql('''
CREATE TABLE youtube_customer (
    customerkey   INTEGER PRIMARY KEY NOT NULL,
    lastname      TEXT,
    birthdate     TEXT,
    maritalstatus TEXT,
    yearlyincome  REAL,
    modifieddate  TEXT,
    etllastupdate TIMESTAMP DEFAULT current_timestamp 
);
''')

# %%
import pandas as pd

# %% [markdown]
# ### Load the master table...

# %%
custdf = pd.read_csv("data/dimcustomer.csv", index_col = False)

# %%
custdf
# Out:
#    customerkey lastname   birthdate maritalstatus  yearlyincome modifieddate
# 0        11000     Yang  1971-10-06             M       90000.0   2019-01-01
# 1        11001    Huang  1976-05-10             S       60000.0   2019-01-01
# 2        11002   Torres  1971-02-09             M       60000.0   2019-01-01
# 3        11003      Zhu  1973-08-14             S       70000.0   2019-01-01

# %% [markdown]
# ### Save the dataframe to a table...
#
# ### Warning!!! Do not use if_exists='replace' or you will lose the primary key because the table gets dropped and created again!

# %%
custdf.to_sql('youtube_customer', conn, if_exists='append', index = False)
# Out:
# 4

# %%
pd.read_sql_query("select * from youtube_customer", conn)
# Out:
#    customerkey lastname   birthdate maritalstatus  yearlyincome modifieddate  \
# 0        11000     Yang  1971-10-06             M       90000.0   2019-01-01
# 1        11001    Huang  1976-05-10             S       60000.0   2019-01-01
# 2        11002   Torres  1971-02-09             M       60000.0   2019-01-01
# 3        11003      Zhu  1973-08-14             S       70000.0   2019-01-01
#
#                etllastupdate
# 0 2025-08-30 17:57:39.510094
# 1 2025-08-30 17:57:39.510094
# 2 2025-08-30 17:57:39.510094
# 3 2025-08-30 17:57:39.510094

# %% [markdown]
# #### Getting meta data...

# %%
# Get table schema...
import pandas as pd 

pd.read_sql_query("""
SELECT * FROM information_schema.columns
WHERE table_name = 'youtube_customer'
ORDER BY ordinal_position
""", conn)
# Out:
#   table_catalog table_schema        table_name    column_name  \
# 0      postgres       public  youtube_customer    customerkey
# 1      postgres       public  youtube_customer       lastname
# 2      postgres       public  youtube_customer      birthdate
# 3      postgres       public  youtube_customer  maritalstatus
# 4      postgres       public  youtube_customer   yearlyincome
# 5      postgres       public  youtube_customer   modifieddate
# 6      postgres       public  youtube_customer  etllastupdate
#
#    ordinal_position     column_default is_nullable  \
# 0                 1               None          NO
# 1                 2               None         YES
# 2                 3               None         YES
# 3                 4               None         YES
# 4                 5               None         YES
# 5                 6               None         YES
# 6                 7  CURRENT_TIMESTAMP         YES
#
#                      data_type character_maximum_length  \
# 0                      integer                     None
# 1                         text                     None
# 2                         text                     None
# 3                         text                     None
# 4                         real                     None
# 5                         text                     None
# 6  timestamp without time zone                     None
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1            1.073742e+09  ...           NO                 None
# 2            1.073742e+09  ...           NO                 None
# 3            1.073742e+09  ...           NO                 None
# 4                     NaN  ...           NO                 None
# 5            1.073742e+09  ...           NO                 None
# 6                     NaN  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
# 3            None                None             None             None
# 4            None                None             None             None
# 5            None                None             None             None
# 6            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
# 4             NO        NEVER                  None          YES
# 5             NO        NEVER                  None          YES
# 6             NO        NEVER                  None          YES
#
# [7 rows x 44 columns]

# %% [markdown]
# ### Lets load the transaction file...

# %%
transdf = pd.read_csv("data/dimcustomertransactions.csv", index_col = None)
transdf
# Out:
#    customerkey lastname   birthdate maritalstatus  yearlyincome actionind  \
# 0        11000     Yang  1971-10-06             M      250000.0         U
# 1        11001    Jones  1976-05-10             S      360000.0         U
# 2       333301   Murhpy  1975-02-09             M       33000.0         A
# 3       333302     Jain  1980-01-09             M       28000.0         A
# 4        11002   Torres  1971-02-09             M       60000.0         D
#
#   modifieddate
# 0   2020-01-01
# 1   2019-02-01
# 2   2018-01-01
# 3   2020-02-01
# 4   2020-02-01

# %%
transdf.to_sql('youtube_custtrans', conn, if_exists='replace', index = False)
pd.read_sql_query("select * from youtube_custtrans", conn)
# Out:
#    customerkey lastname   birthdate maritalstatus  yearlyincome actionind  \
# 0        11000     Yang  1971-10-06             M      250000.0         U
# 1        11001    Jones  1976-05-10             S      360000.0         U
# 2       333301   Murhpy  1975-02-09             M       33000.0         A
# 3       333302     Jain  1980-01-09             M       28000.0         A
# 4        11002   Torres  1971-02-09             M       60000.0         D
#
#   modifieddate
# 0   2020-01-01
# 1   2019-02-01
# 2   2018-01-01
# 3   2020-02-01
# 4   2020-02-01

# %% [markdown]
# ### Let's update the customer table with the transactions.
# - Add    - If the customer is not found, insert transaction as new customer.
# - Change - If the customer is found, update the existing customer with the transaction data.
# - Delete - If the DropInd = 'Y', remove the customer row.

# %% [markdown]
# #### Note:  You must supply column names to allow the ETLLastUpdate to Default...

# %% [markdown]
# _____

# %% [markdown]
# ## Upserting from a transaction table...

# %% [markdown]
# ### Note:  Use PgAdmin to test the Upsert statement!

# %%
#  Sample code - do not execute...
INSERT INTO mytable 
  SELECT * FROM mytransactions 
  ON CONFLICT(keycolumn) 
    DO UPDATE SET columnname=excluded.columnname;

# %% [markdown]
# ####  - You can filter on the transaction table in the query.
# ####  - Notice we do not update BirthDate.

# %%
sql = '''
INSERT INTO youtube_customer(customerkey, lastname, birthdate, maritalstatus, yearlyincome, modifieddate)
  SELECT customerkey, lastname, birthdate, maritalstatus, yearlyincome, modifieddate 
  FROM youtube_custtrans 
  WHERE ActionInd in ('A', 'U')
  ON CONFLICT(customerkey) 
  DO UPDATE SET 
    lastname=excluded.lastname,
    maritalstatus=excluded.maritalstatus,
    yearlyincome = excluded.yearlyincome, 
    modifieddate = excluded.modifieddate,
    etllastupdate = current_timestamp
  WHERE excluded.modifieddate > youtube_customer.modifieddate
'''
print(sql)
# Out:
# INSERT INTO youtube_customer(customerkey, lastname, birthdate, maritalstatus, yearlyincome, modifieddate)
#   SELECT customerkey, lastname, birthdate, maritalstatus, yearlyincome, modifieddate
#   FROM youtube_custtrans
#   WHERE ActionInd in ('A', 'U')
#   ON CONFLICT(customerkey)
#   DO UPDATE SET
#     lastname=excluded.lastname,
#     maritalstatus=excluded.maritalstatus,
#     yearlyincome = excluded.yearlyincome,
#     modifieddate = excluded.modifieddate,
#     etllastupdate = current_timestamp
#   WHERE excluded.modifieddate > youtube_customer.modifieddate

# %%
conn.exec_driver_sql(sql)

# %%
pd.read_sql_query("select * from youtube_custtrans", conn)
# Out:
#    customerkey lastname   birthdate maritalstatus  yearlyincome actionind  \
# 0        11000     Yang  1971-10-06             M      250000.0         U
# 1        11001    Jones  1976-05-10             S      360000.0         U
# 2       333301   Murhpy  1975-02-09             M       33000.0         A
# 3       333302     Jain  1980-01-09             M       28000.0         A
# 4        11002   Torres  1971-02-09             M       60000.0         D
#
#   modifieddate
# 0   2020-01-01
# 1   2019-02-01
# 2   2018-01-01
# 3   2020-02-01
# 4   2020-02-01

# %%
pd.read_sql_query("SELECT * FROM youtube_customer ORDER BY customerkey", conn)
# Out:
#    customerkey lastname   birthdate maritalstatus  yearlyincome modifieddate  \
# 0        11000     Yang  1971-10-06             M      250000.0   2020-01-01
# 1        11001    Jones  1976-05-10             S      360000.0   2019-02-01
# 2        11002   Torres  1971-02-09             M       60000.0   2019-01-01
# 3        11003      Zhu  1973-08-14             S       70000.0   2019-01-01
# 4       333301   Murhpy  1975-02-09             M       33000.0   2018-01-01
# 5       333302     Jain  1980-01-09             M       28000.0   2020-02-01
#
#                etllastupdate
# 0 2025-08-30 17:57:39.510094
# 1 2025-08-30 17:57:39.510094
# 2 2025-08-30 17:57:39.510094
# 3 2025-08-30 17:57:39.510094
# 4 2025-08-30 17:57:39.510094
# 5 2025-08-30 17:57:39.510094

# %%
# Delete
conn.exec_driver_sql('''DELETE FROM youtube_customer  
                WHERE CustomerKey IN (
                SELECT CustomerKey 
                FROM youtube_custtrans where ActionInd = 'D');''')

pd.read_sql_query("select * from youtube_customer ORDER BY customerkey", conn)
# Out:
#    customerkey lastname   birthdate maritalstatus  yearlyincome modifieddate  \
# 0        11000     Yang  1971-10-06             M      250000.0   2020-01-01
# 1        11001    Jones  1976-05-10             S      360000.0   2019-02-01
# 2        11003      Zhu  1973-08-14             S       70000.0   2019-01-01
# 3       333301   Murhpy  1975-02-09             M       33000.0   2018-01-01
# 4       333302     Jain  1980-01-09             M       28000.0   2020-02-01
#
#                etllastupdate
# 0 2025-08-30 17:57:39.510094
# 1 2025-08-30 17:57:39.510094
# 2 2025-08-30 17:57:39.510094
# 3 2025-08-30 17:57:39.510094
# 4 2025-08-30 17:57:39.510094

# %% [markdown]
# # Let's close the connection.

# %%
# conn.dispose()
conn.close()
