# %% [markdown]
# ## Read multiple s3 objects
#
# Let us understand how we can read multiple s3 objects into the collection.
# * Create client using appropriate profile.
# * Get 10 objects using the client.
# * Read the content of all 10 objects into collection

# %%
import boto3
import os
os.environ.setdefault('http_proxy', 'http://webproxy...com:')
os.environ.setdefault('https_proxy', 'http://webproxy...com:')
os.environ.setdefault('AWS_PROFILE', 'itvgenlogs')
BUCKET_NAME = 'itv-genlogs'
PREFIX = 'logs/year'

# %%
s3_client = boto3.client('s3')

# get objects in the bucket and prefix
s3_objects = s3_client.list_objects(
    Bucket=BUCKET_NAME, 
    Prefix=PREFIX
)

# get the keys of the objects only
s3_objects_keys = [ c['Key'] for c in s3_objects['Contents'] ]

# retrieve the content of each object and put them all in one big list
data = []
for key in s3_objects_keys:
    body = s3_client \
        .get_object(Bucket=BUCKET_NAME, Key=key)['Body'] \
        .read() \
        .decode('utf-8') \
        .splitlines()
    data += body

# %%
len(data)
# Out:
# 7074

# %%
data[:5]
# Out:
# ['114.213.54.43 - - [07/Jan/2026:03:14:49 -0800] "GET /categories/world%20cup%20shop/products HTTP/1.1" 200 241 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"',
#  '144.166.145.113 - - [07/Jan/2026:03:14:37 -0800] "GET /department/apparel/categories HTTP/1.1" 200 1531 "-" "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"',
#  '25.45.211.43 - - [07/Jan/2026:03:14:34 -0800] "GET /categories/electronics/products HTTP/1.1" 200 1576 "-" "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"',
#  '192.144.171.52 - - [07/Jan/2026:03:14:52 -0800] "GET /department/apparel/products HTTP/1.1" 200 1844 "-" "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"',
# ...
