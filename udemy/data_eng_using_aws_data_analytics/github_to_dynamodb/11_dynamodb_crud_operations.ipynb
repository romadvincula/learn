# %% [markdown]
# ## Dynamodb CRUD Operations
#
# Let us understand how we can perform basic CRUD operations against Dynamodb table.
# * Create table by name employees.
# * Insert few records.
# * Get one of the record and update.
# * Delete the record and then delete the table.

# %%
import boto3

# %%
import os
os.environ.setdefault('http_proxy', 'http://webproxy...com:')
os.environ.setdefault('https_proxy', 'http://webproxy...com:')
# Out:
# 'http://webproxy.au.harveynorman.com:8080'

# %%
os.environ.setdefault('AWS_PROFILE', 'itvgithub')
# Out:
# 'itvgithub'

# %%
os.environ.setdefault('AWS_DEFAULT_REGION', 'ap-southeast-2')
# Out:
# 'ap-southeast-2'

# %%
dynamodb = boto3.resource('dynamodb')

# %%
table = dynamodb.create_table(
      TableName='employees',
      KeySchema=[
          {
              'AttributeName': 'eid',
              'KeyType': 'HASH'
          },
      ],
      AttributeDefinitions=[
          {
              'AttributeName': 'eid',
              'AttributeType': 'N'              
          },
      ],
      BillingMode='PAY_PER_REQUEST'
  )

# %%
table = dynamodb.Table('employees')

# %%
from decimal import Decimal

# %%
emp1 = {
    'eid': 1,
    'fn': 'Scott',
    'ln': 'Tiger',
    'sal': Decimal('1000.0'),
    'pn': [1234567890, 234567891],
    'a': {
        'a1': '700 ABCD BLVD',
        'c': 'Round Rock',
        's': 'TX',
        'pc': 78665
    }
}

# %%
table.put_item(Item=emp1)
# Out:
# {'ResponseMetadata': {'RequestId': 'DCM52VKH224GG78KCUQQFC5MCFVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Thu, 08 Jan 2026 04:47:36 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'DCM52VKH224GG78KCUQQFC5MCFVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}

# %%
emp2 = {
    'eid': 2,
    'fn': 'Mark',
    'ln': 'Harris',
    'sal': Decimal('2000.0'),
    'pn': [3456789012],
    'a': {
        'a1': '1234 XYZ BLVD',
        'c': 'Irving',
        's': 'TX',
        'pc': 75038
    }
}

# %%
table.put_item(Item=emp2)
# Out:
# {'ResponseMetadata': {'RequestId': 'NESA95445QFF59689MGF3UJ8LBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Thu, 08 Jan 2026 04:47:45 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'NESA95445QFF59689MGF3UJ8LBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}

# %%
table.get_item(Key={'eid': 1})
# Out:
# {'Item': {'a': {'a1': '700 ABCD BLVD',
#    'c': 'Round Rock',
#    's': 'TX',
#    'pc': Decimal('78665')},
#   'fn': 'Scott',
#   'ln': 'Tiger',
#   'eid': Decimal('1'),
#   'pn': [Decimal('1234567890'), Decimal('234567891')],
#   'sal': Decimal('1000')},
#  'ResponseMetadata': {'RequestId': 'TTS95SQFN1RAT5MQ0HU1ORI6TJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Thu, 08 Jan 2026 04:47:50 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '229',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'TTS95SQFN1RAT5MQ0HU1ORI6TJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '133193590'},
#   'RetryAttempts': 0}}

# %%
table.get_item(Key={'eid': 1})['Item']
# Out:
# {'a': {'a1': '700 ABCD BLVD',
#   'c': 'Round Rock',
#   's': 'TX',
#   'pc': Decimal('78665')},
#  'fn': 'Scott',
#  'ln': 'Tiger',
#  'eid': Decimal('1'),
#  'pn': [Decimal('1234567890'), Decimal('234567891')],
#  'sal': Decimal('1000')}

# %%
table.get_item(Key={'eid': 1})['Item']['a']
# Out:
# {'a1': '700 ABCD BLVD', 'c': 'Round Rock', 's': 'TX', 'pc': Decimal('78665')}

# %%
table.get_item(Key={'eid': 1})['Item']['sal']
# Out:
# Decimal('1000')

# %%
item = table.get_item(Key={'eid': 1})['Item']

# %%
item
# Out:
# {'a': {'a1': '700 ABCD BLVD',
#   'c': 'Round Rock',
#   's': 'TX',
#   'pc': Decimal('78665')},
#  'fn': 'Scott',
#  'ln': 'Tiger',
#  'eid': Decimal('1'),
#  'pn': [Decimal('1234567890'), Decimal('234567891')],
#  'sal': Decimal('1000')}

# %%
item['sal'] = Decimal('3500.0')

# %%
table.put_item(Item=item)
# Out:
# {'ResponseMetadata': {'RequestId': '0E1ID6GJE7TBH372ODQU46JBPBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Thu, 08 Jan 2026 04:53:00 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '0E1ID6GJE7TBH372ODQU46JBPBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}

# %%
table.get_item(Key={'eid': 1})['Item']
# Out:
# {'a': {'a1': '700 ABCD BLVD',
#   'c': 'Round Rock',
#   's': 'TX',
#   'pc': Decimal('78665')},
#  'fn': 'Scott',
#  'ln': 'Tiger',
#  'eid': Decimal('1'),
#  'pn': [Decimal('1234567890'), Decimal('234567891')],
#  'sal': Decimal('3500')}

# %%
table.get_item(Key={'eid': 2})['Item']
# Out:
# {'a': {'a1': '1234 XYZ BLVD',
#   'c': 'Irving',
#   's': 'TX',
#   'pc': Decimal('75038')},
#  'fn': 'Mark',
#  'ln': 'Harris',
#  'eid': Decimal('2'),
#  'pn': [Decimal('3456789012')],
#  'sal': Decimal('2000')}

# %%
table.scan()
# Out:
# {'Items': [{'a': {'a1': '1234 XYZ BLVD',
#     'c': 'Irving',
#     's': 'TX',
#     'pc': Decimal('75038')},
#    'fn': 'Mark',
#    'ln': 'Harris',
#    'eid': Decimal('2'),
#    'pn': [Decimal('3456789012')],
#    'sal': Decimal('2000')},
#   {'a': {'a1': '700 ABCD BLVD',
#     'c': 'Round Rock',
#     's': 'TX',
#     'pc': Decimal('78665')},
#    'fn': 'Scott',
#    'ln': 'Tiger',
#    'eid': Decimal('1'),
#    'pn': [Decimal('1234567890'), Decimal('234567891')],
#    'sal': Decimal('3500')}],
#  'Count': 2,
#  'ScannedCount': 2,
#  'ResponseMetadata': {'RequestId': 'J42T88GEQRCI49M92MBTRSK9QJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Thu, 08 Jan 2026 04:55:22 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '458',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'J42T88GEQRCI49M92MBTRSK9QJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '234094455'},
#   'RetryAttempts': 0}}

# %%
items = table.scan()['Items']

# %%
for item in items:
    print(f'Salary of {item["eid"]} is {item["sal"]}')
# Out:
# Salary of 2 is 2000
# Salary of 1 is 3500

# %%
table.delete_item(Key={'eid': 1})
# Out:
# {'ResponseMetadata': {'RequestId': 'Q3J1BTS5K9FNT5V7S48Q5NNA1FVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Thu, 08 Jan 2026 04:56:10 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'Q3J1BTS5K9FNT5V7S48Q5NNA1FVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}

# %%
table.scan()
# Out:
# {'Items': [{'a': {'a1': '1234 XYZ BLVD',
#     'c': 'Irving',
#     's': 'TX',
#     'pc': Decimal('75038')},
#    'fn': 'Mark',
#    'ln': 'Harris',
#    'eid': Decimal('2'),
#    'pn': [Decimal('3456789012')],
#    'sal': Decimal('2000')}],
#  'Count': 1,
#  'ScannedCount': 1,
#  'ResponseMetadata': {'RequestId': '5NEO8HPOV9E3IUG9081NUJS3INVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Thu, 08 Jan 2026 04:56:11 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '237',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '5NEO8HPOV9E3IUG9081NUJS3INVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '971034959'},
#   'RetryAttempts': 0}}

# %%
table.delete()
# Out:
# {'TableDescription': {'TableName': 'employees',
#   'TableStatus': 'DELETING',
#   'ProvisionedThroughput': {'NumberOfDecreasesToday': 0,
#    'ReadCapacityUnits': 0,
#    'WriteCapacityUnits': 0},
#   'TableSizeBytes': 0,
#   'ItemCount': 0,
#   'TableArn': 'arn:aws:dynamodb:ap-southeast-2:222634372385:table/employees',
#   'TableId': 'fa26794d-a19c-4dc9-9932-a59f6b65c1bc',
#   'BillingModeSummary': {'BillingMode': 'PAY_PER_REQUEST',
#    'LastUpdateToPayPerRequestDateTime': datetime.datetime(2026, 1, 8, 15, 47, 10, 844000, tzinfo=tzlocal())},
#   'DeletionProtectionEnabled': False},
#  'ResponseMetadata': {'RequestId': 'MJJ6KNOCHBN4P6TVVPVFUTU9EJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Thu, 08 Jan 2026 04:56:19 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '591',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'MJJ6KNOCHBN4P6TVVPVFUTU9EJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '1842213928'},
#   'RetryAttempts': 0}}

# %%
# %%sh
#
# aws dynamodb list-tables --profile itvgithub --region ap-southeast-2
# Out:
# {
#     "TableNames": [
#         "ghmarker",
#         "ghrepos"
#     ]
# }
