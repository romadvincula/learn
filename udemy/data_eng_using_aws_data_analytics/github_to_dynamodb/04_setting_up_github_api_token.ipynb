# %% [markdown]
# ## Setting up GitHub API Token
#
# Let us go ahead and setup GitHub API Token so that we can make up to 5000 API calls per hour.
# * With out token we can only invoke handful of API calls per hour.
# * You need to go to your GitHub account to create token.
# * Once you create the token either you can use `curl` or Python `requests` library to invoke the GitHub APIs to get the data.

# %%
import os
os.environ.setdefault('http_proxy', 'webproxy...com:')
os.environ.setdefault('https_proxy', 'webproxy...com:')

TOKEN = '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'

# %%
# %%sh
#
# curl -u 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 https://api.github.com/user

# %%
import requests

# %%
res = requests.get(
    'https://api.github.com/user',
    headers={'Authorization': f"token {TOKEN}"},
    verify=False
)

# %%
res.content

# %%
res.content.decode('utf-8')

# %%
import json
content = res.content.decode('utf-8')
user = json.loads(content)

# %%
type(user)
# Out:
# dict

# %%
user['login']
