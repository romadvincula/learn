# %% [markdown]
# ## Extracting required information
#
# Let us see how we can extract required information using GitHub APIs. We will be using **list public repositories** and then **get repository** using id.
# * Get list of repositories using since.
# * Pick one repo details and then get details about specific repository.

# %%
import os
os.environ.setdefault('http_proxy', 'http://webproxy...com:')
os.environ.setdefault('https_proxy', 'http://webproxy...com:')

TOKEN = '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'

# %%
import requests

# %%
# %%sh
#
# curl \
#     -H "Accept: application/vnd.github.v3+json" \
#     https://api.github.com/repositories?since=333255899

# %%
res = requests.get(
    'https://api.github.com/repositories?since=333255899',
    headers={'Authorization': f'token {TOKEN}'},
    verify=False
)
# Out:
# /home/arldvincula/miniconda3/envs/py310/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.au.harveynorman.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
type(res)
# Out:
# requests.models.Response

# %%
res.content.decode('utf-8')

# %%
import json
repos = json.loads(res.content.decode('utf-8'))

# %%
type(repos)
# Out:
# list

# %%
len(repos)
# Out:
# 100

# %%
repos[:3]
# Out:
# [{'id': 333255904,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzMyNTU5MDQ=',
#   'name': 'renovatebot.github.io',
#   'full_name': 'ConnectionMaster/renovatebot.github.io',
#   'private': False,
#   'owner': {'login': 'ConnectionMaster',
#    'id': 49809193,
#    'node_id': 'MDQ6VXNlcjQ5ODA5MTkz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49809193?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ConnectionMaster',
#    'html_url': 'https://github.com/ConnectionMaster',
#    'followers_url': 'https://api.github.com/users/ConnectionMaster/followers',
#    'following_url': 'https://api.github.com/users/ConnectionMaster/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ConnectionMaster/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ConnectionMaster/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ConnectionMaster/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ConnectionMaster/orgs',
#    'repos_url': 'https://api.github.com/users/ConnectionMaster/repos',
#    'events_url': 'https://api.github.com/users/ConnectionMaster/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ConnectionMaster/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/ConnectionMaster/renovatebot.github.io',
#   'description': 'Auto-generating docs repository for Renovate Bot',
#   'fork': True,
#   'url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io',
#   'forks_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/forks',
#   'keys_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/teams',
#   'hooks_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/hooks',
#   'issue_events_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/events',
#   'assignees_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/tags',
#   'blobs_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/languages',
#   'stargazers_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/stargazers',
#   'contributors_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/contributors',
#   'subscribers_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/subscription',
#   'commits_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/merges',
#   'archive_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/downloads',
#   'issues_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/deployments'},
#  {'id': 333255905,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzMyNTU5MDU=',
#   'name': 'cvv',
#   'full_name': 'jorgecardenas9006/cvv',
#   'private': False,
#   'owner': {'login': 'jorgecardenas9006',
#    'id': 27660779,
#    'node_id': 'MDQ6VXNlcjI3NjYwNzc5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27660779?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorgecardenas9006',
#    'html_url': 'https://github.com/jorgecardenas9006',
#    'followers_url': 'https://api.github.com/users/jorgecardenas9006/followers',
#    'following_url': 'https://api.github.com/users/jorgecardenas9006/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorgecardenas9006/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorgecardenas9006/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorgecardenas9006/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorgecardenas9006/orgs',
#    'repos_url': 'https://api.github.com/users/jorgecardenas9006/repos',
#    'events_url': 'https://api.github.com/users/jorgecardenas9006/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorgecardenas9006/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/jorgecardenas9006/cvv',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/jorgecardenas9006/cvv',
#   'forks_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/forks',
#   'keys_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/teams',
#   'hooks_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/hooks',
#   'issue_events_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/events',
#   'assignees_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/tags',
#   'blobs_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/languages',
#   'stargazers_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/stargazers',
#   'contributors_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/contributors',
#   'subscribers_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/subscribers',
#   'subscription_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/subscription',
#   'commits_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/merges',
#   'archive_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/downloads',
#   'issues_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/jorgecardenas9006/cvv/deployments'},
#  {'id': 333255907,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzMyNTU5MDc=',
#   'name': 'ng-qubee',
#   'full_name': 'AndreaAlhena/ng-qubee',
#   'private': False,
#   'owner': {'login': 'AndreaAlhena',
#    'id': 5293530,
#    'node_id': 'MDQ6VXNlcjUyOTM1MzA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5293530?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AndreaAlhena',
#    'html_url': 'https://github.com/AndreaAlhena',
#    'followers_url': 'https://api.github.com/users/AndreaAlhena/followers',
#    'following_url': 'https://api.github.com/users/AndreaAlhena/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/AndreaAlhena/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/AndreaAlhena/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/AndreaAlhena/subscriptions',
#    'organizations_url': 'https://api.github.com/users/AndreaAlhena/orgs',
#    'repos_url': 'https://api.github.com/users/AndreaAlhena/repos',
#    'events_url': 'https://api.github.com/users/AndreaAlhena/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/AndreaAlhena/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/AndreaAlhena/ng-qubee',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee',
#   'forks_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/forks',
#   'keys_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/teams',
#   'hooks_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/hooks',
#   'issue_events_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/events',
#   'assignees_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/tags',
#   'blobs_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/languages',
#   'stargazers_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/stargazers',
#   'contributors_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/contributors',
#   'subscribers_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/subscription',
#   'commits_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/merges',
#   'archive_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/downloads',
#   'issues_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/AndreaAlhena/ng-qubee/deployments'}]

# %%
repos[-1]
# Out:
# {'id': 333256168,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzMzMyNTYxNjg=',
#  'name': 'Mary-Qu-Otis',
#  'full_name': 'MaryQu/Mary-Qu-Otis',
#  'private': False,
#  'owner': {'login': 'MaryQu',
#   'id': 78056973,
#   'node_id': 'MDQ6VXNlcjc4MDU2OTcz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/78056973?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/MaryQu',
#   'html_url': 'https://github.com/MaryQu',
#   'followers_url': 'https://api.github.com/users/MaryQu/followers',
#   'following_url': 'https://api.github.com/users/MaryQu/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/MaryQu/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/MaryQu/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/MaryQu/subscriptions',
#   'organizations_url': 'https://api.github.com/users/MaryQu/orgs',
#   'repos_url': 'https://api.github.com/users/MaryQu/repos',
#   'events_url': 'https://api.github.com/users/MaryQu/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/MaryQu/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False},
#  'html_url': 'https://github.com/MaryQu/Mary-Qu-Otis',
#  'description': None,
#  'fork': False,
#  'url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis',
#  'forks_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/forks',
#  'keys_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/teams',
#  'hooks_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/hooks',
#  'issue_events_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/events',
#  'assignees_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/tags',
#  'blobs_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/languages',
#  'stargazers_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/stargazers',
#  'contributors_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/contributors',
#  'subscribers_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/subscribers',
#  'subscription_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/subscription',
#  'commits_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/merges',
#  'archive_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/downloads',
#  'issues_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/MaryQu/Mary-Qu-Otis/deployments'}

# %%
for repo in repos:
    print({'id': repo['id'], 'owner.login': repo['owner']['login'], 'name': repo['name']})
# Out:
# {'id': 333255904, 'owner.login': 'ConnectionMaster', 'name': 'renovatebot.github.io'}
# {'id': 333255905, 'owner.login': 'jorgecardenas9006', 'name': 'cvv'}
# {'id': 333255907, 'owner.login': 'AndreaAlhena', 'name': 'ng-qubee'}
# {'id': 333255908, 'owner.login': 'Microsvuln', 'name': 'drafts'}
# {'id': 333255912, 'owner.login': '1152545264', 'name': 'funNLP'}
# {'id': 333255917, 'owner.login': 'aohg0', 'name': 'dvrjbddxws'}
# {'id': 333255920, 'owner.login': 'andrewfriedman20', 'name': 'prework-about-me'}
# {'id': 333255922, 'owner.login': 'LupitaMoreno', 'name': 'lab-intro-to-ml'}
# {'id': 333255923, 'owner.login': 'brandonPerez206', 'name': 'checkout'}
# {'id': 333255925, 'owner.login': 'Ohimrok2021', 'name': 'Drycons-Peru-web'}
# {'id': 333255927, 'owner.login': 'joe-coder-01', 'name': 'SmartHotel360-Website'}
# {'id': 333255929, 'owner.login': 't4c67abh', 'name': 'inxxxzvmow'}
# {'id': 333255930, 'owner.login': 'JonathanSaunders98', 'name': 'ucf-project-1'}
# {'id': 333255931, 'owner.login': 'mixestre13', 'name': 'rumini-app'}
# {'id': 333255932, 'owner.login': 'zgh3783', 'name': 'zhzrsnhsig'}
# {'id': 333255934, 'owner.login': 'xxczaki', 'name': 'storage-async'}
# {'id': 333255938, 'owner.login': 'tt9wpidr', 'name': 'tvzomrqocv'}
# {'id': 333255939, 'owner.login': 'adriano-sena', 'name': 'gol-quiz'}
# {'id': 333255941, 'owner.login': 'ribs-team', 'name': 'strapi'}
# {'id': 333255943, 'owner.login': 'yousefsaqoul', 'name': 'The-design-shop-'}
# {'id': 333255954, 'owner.login': 'blldw', 'name': 'latex-resources'}
# {'id': 333255955, 'owner.login': 'devanup', 'name': 'css-challenges'}
# {'id': 333255956, 'owner.login': 'ianlevesque', 'name': 'tilt-brush'}
# {'id': 333255957, 'owner.login': 'ffn13on1', 'name': 'uvbjfuwdki'}
# {'id': 333255958, 'owner.login': 'davidzhangcoder', 'name': 'webpack-study'}
# {'id': 333255959, 'owner.login': 'le-sambestia', 'name': 'scuffedstreams'}
# {'id': 333255961, 'owner.login': 'bambiteague', 'name': 'rack-dynamic-routes-lab'}
# {'id': 333255964, 'owner.login': 'gabrieldegiorgi', 'name': 'Curso.Prep.Henry'}
# {'id': 333255967, 'owner.login': 'adamabad', 'name': 'SquidBot'}
# {'id': 333255969, 'owner.login': 'prfz44ig', 'name': 'bvcbotroch'}
# {'id': 333255970, 'owner.login': 'jtk5469', 'name': 'TAD_2021'}
# {'id': 333255975, 'owner.login': 'bethpresten', 'name': 'portfolio'}
# {'id': 333255977, 'owner.login': 'tahmid-saj', 'name': 'ELE882-lab2'}
# {'id': 333255978, 'owner.login': 'welitoncardozo', 'name': 'order-of-service-api'}
# {'id': 333255979, 'owner.login': 'cisc322', 'name': 'Jami-ing-Out'}
# {'id': 333255984, 'owner.login': 'greenbc', 'name': 'week4_day2_hw'}
# {'id': 333255985, 'owner.login': 'acc-cosc-1337-spring-2021', 'name': 'acc-cosc-1337-spring-2021-ccakefist'}
# {'id': 333255988, 'owner.login': 'BenjaminHaaseT', 'name': 'CSC3220-Project02'}
# {'id': 333255994, 'owner.login': 'Chunde', 'name': 'DeepSpeed'}
# {'id': 333255996, 'owner.login': 'dmmulroy', 'name': 'next-auth'}
# {'id': 333255997, 'owner.login': 'douglassimaodev', 'name': 'agenda'}
# {'id': 333256002, 'owner.login': 'ConnectionMaster', 'name': 'docker-node-1'}
# {'id': 333256008, 'owner.login': 'atnjqt', 'name': 'docker-lamp'}
# {'id': 333256010, 'owner.login': 'Raya-Sodwilai', 'name': 'practice-indentation-and-spacing'}
# {'id': 333256011, 'owner.login': 'RafRunner', 'name': 'MeusGames'}
# {'id': 333256012, 'owner.login': 'michaeladam', 'name': 'one-click-hugo-cms'}
# {'id': 333256013, 'owner.login': 'MatthewAhumada', 'name': 'git-lab-2'}
# {'id': 333256015, 'owner.login': 'GabrielVolpatoP', 'name': 'Django_Senai'}
# {'id': 333256019, 'owner.login': 'taoyuchuan', 'name': 'ReactHook'}
# {'id': 333256028, 'owner.login': 'teynav', 'name': 'stickers'}
# {'id': 333256032, 'owner.login': 'skyformat99', 'name': 'kitty-2'}
# {'id': 333256034, 'owner.login': 'olci34', 'name': 'ruby-oo-inheritance-defining-inheritance'}
# {'id': 333256036, 'owner.login': 'nyabkun', 'name': 'globbing'}
# {'id': 333256037, 'owner.login': 'PatriotPartyCoin', 'name': 'Patriot-Party-Coin'}
# {'id': 333256038, 'owner.login': 'Mathprestes', 'name': 'Exercicios-de-Linguagem-Java'}
# {'id': 333256039, 'owner.login': 'smartappcoder', 'name': 'ecommerce-react-graphql-stripe'}
# {'id': 333256040, 'owner.login': 'ashrithaaadibhatla', 'name': 'Project-22'}
# {'id': 333256041, 'owner.login': 'v1zconde', 'name': 'employee_Tracker'}
# {'id': 333256042, 'owner.login': 'parkallen12-appdev', 'name': 'ruby-gym'}
# {'id': 333256043, 'owner.login': 'Riviera12345', 'name': 'batch2bash'}
# {'id': 333256045, 'owner.login': 'Tryweirder', 'name': 'connect-java-sdk'}
# {'id': 333256046, 'owner.login': 'ljxQAQ', 'name': 'JD_Sign_Action'}
# {'id': 333256047, 'owner.login': 'JamieWilsonDev', 'name': 'MessingAround'}
# {'id': 333256050, 'owner.login': 'fm1539', 'name': 'Voter-Eligibility'}
# {'id': 333256051, 'owner.login': 'Ivanpau1', 'name': 'MuskCult'}
# {'id': 333256052, 'owner.login': 'askpatrickw', 'name': 'Adafruit_CircuitPython_SimpleIO'}
# {'id': 333256053, 'owner.login': 'Albatrossms', 'name': 'smart-contract-truffle-1'}
# {'id': 333256059, 'owner.login': 'WatchAndyTW', 'name': 'AgarthaLib'}
# {'id': 333256062, 'owner.login': 'muhtorres', 'name': 'gostack-desafio01-nodejs'}
# {'id': 333256065, 'owner.login': 'sdrobert', 'name': 'html-exam-poc'}
# {'id': 333256067, 'owner.login': 'NajeraDev', 'name': 'js-desafio2'}
# {'id': 333256084, 'owner.login': 'CandyDevices', 'name': 'device_google_sunfish'}
# {'id': 333256087, 'owner.login': 'poym154', 'name': 'icoesqsrmc'}
# {'id': 333256094, 'owner.login': 'allancampos', 'name': 'garage'}
# {'id': 333256095, 'owner.login': 'engcfraposo', 'name': 'gostack-template-fundamentos-node'}
# {'id': 333256102, 'owner.login': 'rgzw433', 'name': 'pxhjpptxnp'}
# {'id': 333256107, 'owner.login': 'NuranTerlan', 'name': 'designpatterns-csharp'}
# {'id': 333256108, 'owner.login': 'soundgnome', 'name': 'mutebox'}
# {'id': 333256109, 'owner.login': 'neyoalao', 'name': 'UsefulCommandsAPIFrontEnd'}
# {'id': 333256113, 'owner.login': 'harrypod', 'name': 'go-mssqldb'}
# {'id': 333256115, 'owner.login': 'filiperaiz', 'name': 'quizraiz'}
# {'id': 333256118, 'owner.login': 'jacksari', 'name': 'te-station-html-css'}
# {'id': 333256120, 'owner.login': 'Icvza', 'name': 'active-record-intro-to-rake'}
# {'id': 333256121, 'owner.login': 'iamvkv', 'name': 'www.blockchaincommons.com'}
# {'id': 333256125, 'owner.login': 'msmic1', 'name': 'przovsfcsn'}
# {'id': 333256129, 'owner.login': 'HugoGarraway', 'name': 'tresure_GAME'}
# {'id': 333256133, 'owner.login': 'TrVaughan', 'name': 'Exercise-01b-First-Twine-Project'}
# {'id': 333256137, 'owner.login': 'ohharsen', 'name': 'wi21-cse110-lab4'}
# {'id': 333256139, 'owner.login': 'RainierMM', 'name': 'socket-chat'}
# {'id': 333256140, 'owner.login': 'agentofuser', 'name': 'athens'}
# {'id': 333256141, 'owner.login': 'hwswin', 'name': 'bootswatch'}
# {'id': 333256142, 'owner.login': 'Ariana200', 'name': 'ProgrammingAssignment2'}
# {'id': 333256146, 'owner.login': 'zyzy99', 'name': 'zhangyu'}
# {'id': 333256150, 'owner.login': 'dmytzo', 'name': 'design-patterns-python'}
# {'id': 333256153, 'owner.login': 'YoSoyTonny', 'name': 'clase_Emiliano_26_01_21'}
# {'id': 333256155, 'owner.login': 'shad-waengdu', 'name': 'Weather-Prediction'}
# {'id': 333256157, 'owner.login': 'ConnectionMaster', 'name': 'approve-bot'}
# {'id': 333256164, 'owner.login': 'sawadaikuma', 'name': 'my-go-gql-sample'}
# {'id': 333256165, 'owner.login': 'JustinAldair', 'name': 'repositorioGitHub'}
# {'id': 333256168, 'owner.login': 'MaryQu', 'name': 'Mary-Qu-Otis'}

# %%
repo = repos[0]

# %%
repo['name']
# Out:
# 'renovatebot.github.io'

# %%
repo['owner']['login']
# Out:
# 'ConnectionMaster'

# %%
owner = repo['owner']['login']
name = repo['name']
res = requests.get(
    f'https://api.github.com/repos/{owner}/{name}',
    headers={'Authorization': f'token {TOKEN}'},
    verify=False
)
# Out:
# /home/arldvincula/miniconda3/envs/py310/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.au.harveynorman.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
json.loads(res.content.decode('utf-8'))
# Out:
# {'id': 333255904,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzMzMyNTU5MDQ=',
#  'name': 'renovatebot.github.io',
#  'full_name': 'ConnectionMaster/renovatebot.github.io',
#  'private': False,
#  'owner': {'login': 'ConnectionMaster',
#   'id': 49809193,
#   'node_id': 'MDQ6VXNlcjQ5ODA5MTkz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/49809193?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ConnectionMaster',
#   'html_url': 'https://github.com/ConnectionMaster',
#   'followers_url': 'https://api.github.com/users/ConnectionMaster/followers',
#   'following_url': 'https://api.github.com/users/ConnectionMaster/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ConnectionMaster/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ConnectionMaster/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ConnectionMaster/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ConnectionMaster/orgs',
#   'repos_url': 'https://api.github.com/users/ConnectionMaster/repos',
#   'events_url': 'https://api.github.com/users/ConnectionMaster/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ConnectionMaster/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False},
#  'html_url': 'https://github.com/ConnectionMaster/renovatebot.github.io',
#  'description': 'Auto-generating docs repository for Renovate Bot',
#  'fork': True,
#  'url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io',
#  'forks_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/forks',
#  'keys_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/teams',
#  'hooks_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/hooks',
#  'issue_events_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/events',
#  'assignees_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/tags',
#  'blobs_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/languages',
#  'stargazers_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/stargazers',
#  'contributors_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/contributors',
#  'subscribers_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/subscribers',
#  'subscription_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/subscription',
#  'commits_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/merges',
#  'archive_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/downloads',
#  'issues_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/ConnectionMaster/renovatebot.github.io/deployments',
#  'created_at': '2021-01-27T00:28:11Z',
#  'updated_at': '2021-01-27T00:28:13Z',
#  'pushed_at': '2023-04-04T00:44:50Z',
#  'git_url': 'git://github.com/ConnectionMaster/renovatebot.github.io.git',
#  'ssh_url': 'git@github.com:ConnectionMaster/renovatebot.github.io.git',
#  'clone_url': 'https://github.com/ConnectionMaster/renovatebot.github.io.git',
#  'svn_url': 'https://github.com/ConnectionMaster/renovatebot.github.io',
#  'homepage': 'https://docs.renovatebot.com',
#  'size': 2271,
#  'stargazers_count': 0,
#  'watchers_count': 0,
#  'language': None,
#  'has_issues': False,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': False,
#  'has_pages': False,
#  'has_discussions': False,
#  'forks_count': 0,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 3,
#  'license': None,
#  'allow_forking': True,
#  'is_template': False,
#  'web_commit_signoff_required': False,
#  'topics': [],
#  'visibility': 'public',
#  'forks': 0,
#  'open_issues': 3,
#  'watchers': 0,
#  'default_branch': 'build',
#  'permissions': {'admin': False,
#   'maintain': False,
#   'push': False,
#   'triage': False,
#   'pull': True},
#  'parent': {'id': 239683188,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzk2ODMxODg=',
#   'name': 'renovatebot.github.io',
#   'full_name': 'renovatebot/renovatebot.github.io',
#   'private': False,
#   'owner': {'login': 'renovatebot',
#    'id': 38656520,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4NjU2NTIw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38656520?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovatebot',
#    'html_url': 'https://github.com/renovatebot',
#    'followers_url': 'https://api.github.com/users/renovatebot/followers',
#    'following_url': 'https://api.github.com/users/renovatebot/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/renovatebot/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/renovatebot/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/renovatebot/subscriptions',
#    'organizations_url': 'https://api.github.com/users/renovatebot/orgs',
#    'repos_url': 'https://api.github.com/users/renovatebot/repos',
#    'events_url': 'https://api.github.com/users/renovatebot/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/renovatebot/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/renovatebot/renovatebot.github.io',
#   'description': 'Auto-generating docs repository for Renovate Bot',
#   'fork': False,
#   'url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io',
#   'forks_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/forks',
#   'keys_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/teams',
#   'hooks_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/hooks',
#   'issue_events_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/events',
#   'assignees_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/tags',
#   'blobs_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/languages',
#   'stargazers_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/stargazers',
#   'contributors_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/contributors',
#   'subscribers_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/subscribers',
#   'subscription_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/subscription',
#   'commits_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/merges',
#   'archive_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/downloads',
#   'issues_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/deployments',
#   'created_at': '2020-02-11T05:24:08Z',
#   'updated_at': '2026-01-07T22:20:40Z',
#   'pushed_at': '2026-01-07T22:22:38Z',
#   'git_url': 'git://github.com/renovatebot/renovatebot.github.io.git',
#   'ssh_url': 'git@github.com:renovatebot/renovatebot.github.io.git',
#   'clone_url': 'https://github.com/renovatebot/renovatebot.github.io.git',
#   'svn_url': 'https://github.com/renovatebot/renovatebot.github.io',
#   'homepage': 'https://docs.renovatebot.com',
#   'size': 13245,
#   'stargazers_count': 57,
#   'watchers_count': 57,
#   'language': 'TypeScript',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 37,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 8,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 37,
#   'open_issues': 8,
#   'watchers': 57,
#   'default_branch': 'main'},
#  'source': {'id': 239683188,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzk2ODMxODg=',
#   'name': 'renovatebot.github.io',
#   'full_name': 'renovatebot/renovatebot.github.io',
#   'private': False,
#   'owner': {'login': 'renovatebot',
#    'id': 38656520,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4NjU2NTIw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38656520?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovatebot',
#    'html_url': 'https://github.com/renovatebot',
#    'followers_url': 'https://api.github.com/users/renovatebot/followers',
#    'following_url': 'https://api.github.com/users/renovatebot/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/renovatebot/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/renovatebot/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/renovatebot/subscriptions',
#    'organizations_url': 'https://api.github.com/users/renovatebot/orgs',
#    'repos_url': 'https://api.github.com/users/renovatebot/repos',
#    'events_url': 'https://api.github.com/users/renovatebot/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/renovatebot/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/renovatebot/renovatebot.github.io',
#   'description': 'Auto-generating docs repository for Renovate Bot',
#   'fork': False,
#   'url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io',
#   'forks_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/forks',
#   'keys_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/teams',
#   'hooks_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/hooks',
#   'issue_events_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/events',
#   'assignees_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/tags',
#   'blobs_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/languages',
#   'stargazers_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/stargazers',
#   'contributors_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/contributors',
#   'subscribers_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/subscribers',
#   'subscription_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/subscription',
#   'commits_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/merges',
#   'archive_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/downloads',
#   'issues_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/renovatebot/renovatebot.github.io/deployments',
#   'created_at': '2020-02-11T05:24:08Z',
#   'updated_at': '2026-01-07T22:20:40Z',
#   'pushed_at': '2026-01-07T22:22:38Z',
#   'git_url': 'git://github.com/renovatebot/renovatebot.github.io.git',
#   'ssh_url': 'git@github.com:renovatebot/renovatebot.github.io.git',
#   'clone_url': 'https://github.com/renovatebot/renovatebot.github.io.git',
#   'svn_url': 'https://github.com/renovatebot/renovatebot.github.io',
#   'homepage': 'https://docs.renovatebot.com',
#   'size': 13245,
#   'stargazers_count': 57,
#   'watchers_count': 57,
#   'language': 'TypeScript',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 37,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 8,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 37,
#   'open_issues': 8,
#   'watchers': 57,
#   'default_branch': 'main'},
#  'network_count': 37,
#  'subscribers_count': 0}
