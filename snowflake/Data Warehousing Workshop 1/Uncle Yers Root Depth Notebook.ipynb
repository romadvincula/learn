# %% [markdown]
# # Add rows to Flower detail table
# Edit the "set" cells to update the variable, then click "Run all" in the top left-corner.

# %%
%%sql -r dataframe_4
set rdc = 'M';

# %%
%%sql -r dataframe_3
set fn = 'Tulip';

# %%
%%sql -r dataframe_5
select $fn, $rdc;

# %%
%%sql -r dataframe_1
insert into garden_plants.flowers.flower_details
select $fn, $rdc;

# %%
%%sql -r dataframe_2
select  * from garden_plants.flowers.flower_details

# %%
# # delete row if needed
# delete from garden_plants.flowers.flower_details
# where plant_name = 'Sunflower' and root_depth_code = 'S';
